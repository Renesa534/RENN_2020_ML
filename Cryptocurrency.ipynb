# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")

# %%
data = pd.read_csv("bitcoin.csv")
data = data.sort_values('Date')
data.head()
# Out:
#             Date  Symbol   Open   High     Low  Close  Volume BTC  Volume USD
# 2000  2014-12-01  BTCUSD  300.0  370.0  300.00  370.0     0.05656       19.53
# 1999  2014-12-02  BTCUSD  370.0  378.0  370.00  378.0    15.01000     5675.07
# 1998  2014-12-03  BTCUSD  378.0  378.0  377.01  378.0     0.54660      206.52
# 1997  2014-12-04  BTCUSD  378.0  378.0  377.10  377.1     0.01000        3.77
# 1996  2014-12-05  BTCUSD  377.1  377.1  377.10  377.1     0.00000        0.00

# %%
price = data[['Close']]

plt.figure(figsize = (15,9))
plt.plot(price)
plt.xticks(range(0, data.shape[0],50), data['Date'].loc[::50],rotation=45)
plt.title("Bitcoin Price",fontsize=18, fontweight='bold')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price (USD)',fontsize=18)
plt.show()

# %%
price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2001 entries, 2000 to 0
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2001 non-null   float64
# dtypes: float64(1)
# memory usage: 31.3 KB

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

norm_data = min_max_scaler.fit_transform(price.values)

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i)
    # Reshape data from (history_size,) to (history_size, 1)
    data.append(np.reshape(dataset[indices], (history_size, 1)))
    labels.append(dataset[i+target_size])
  return np.array(data), np.array(labels)

past_history = 5
future_target = 0

TRAIN_SPLIT = int(len(norm_data) * 0.8)


x_train, y_train = univariate_data(norm_data,
                                   0,
                                   TRAIN_SPLIT,
                                   past_history,
                                   future_target)

x_test, y_test = univariate_data(norm_data,
                                 TRAIN_SPLIT,
                                 None,
                                 past_history,
                                 future_target)

# %%
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Dense, LSTM, LeakyReLU, Dropout

num_units = 128
learning_rate = 0.001
activation_function = 'sigmoid'
adam = Adam(lr=learning_rate)
loss_function = 'mse'
batch_size = 5
num_epochs = 50

# Initialize the RNN
model = Sequential()
model.add(LSTM(units = num_units, activation=activation_function, input_shape=(None, 1)))
model.add(LeakyReLU(alpha=0.5))
model.add(Dropout(0.1))
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer=adam, loss=loss_function)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               66560
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Using the training set to train the model
history = model.fit(
    x_train,
    y_train,
    validation_split=0.1,
    batch_size=batch_size,
    epochs=num_epochs,
    shuffle=False
)
# Out:
# Epoch 1/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0294 - val_loss: 0.0117
# Epoch 2/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0172 - val_loss: 0.0152
# Epoch 3/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0141 - val_loss: 0.0187
# Epoch 4/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0136 - val_loss: 0.0126
# Epoch 5/50
# 287/287 [==============================] - 2s 5ms/step - loss: 0.0130 - val_loss: 0.0115
# Epoch 6/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0118 - val_loss: 0.0135
# Epoch 7/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0116 - val_loss: 0.0113
# Epoch 8/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0105 - val_loss: 0.0158
# Epoch 9/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0107 - val_loss: 0.0151
# Epoch 10/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0106 - val_loss: 0.0164
# Epoch 11/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0107 - val_loss: 0.0154
# Epoch 12/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0105 - val_loss: 0.0161
# Epoch 13/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0106 - val_loss: 0.0147
# Epoch 14/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0112 - val_loss: 0.0150
# Epoch 15/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0115 - val_loss: 0.0125
# Epoch 16/50
# 287/287 [==============================] - 2s 6ms/step - loss: 0.0118 - val_loss: 0.0126
# Epoch 17/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0123 - val_loss: 0.0120
# Epoch 18/50
# 287/287 [==============================] - 2s 6ms/step - loss: 0.0130 - val_loss: 0.0123
# Epoch 19/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0143 - val_loss: 0.0114
# Epoch 20/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0161 - val_loss: 0.0122
# Epoch 21/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0175 - val_loss: 0.0134
# Epoch 22/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0204 - val_loss: 0.0114
# Epoch 23/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0232 - val_loss: 0.0098
# Epoch 24/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0233 - val_loss: 0.0086
# Epoch 25/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0215 - val_loss: 0.0080
# Epoch 26/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0183 - val_loss: 0.0072
# Epoch 27/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0144 - val_loss: 0.0059
# Epoch 28/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0102 - val_loss: 0.0045
# Epoch 29/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0072 - val_loss: 0.0031
# Epoch 30/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0056 - val_loss: 0.0029
# Epoch 31/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0048 - val_loss: 0.0026
# Epoch 32/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0045 - val_loss: 0.0027
# Epoch 33/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0042 - val_loss: 0.0031
# Epoch 34/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0031
# Epoch 35/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0033
# Epoch 36/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0041 - val_loss: 0.0032
# Epoch 37/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0042 - val_loss: 0.0032
# Epoch 38/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0041 - val_loss: 0.0036
# Epoch 39/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0041 - val_loss: 0.0030
# Epoch 40/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0040 - val_loss: 0.0032
# Epoch 41/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0040 - val_loss: 0.0031
# Epoch 42/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0041 - val_loss: 0.0027
# Epoch 43/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0038 - val_loss: 0.0033
# Epoch 44/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 45/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 46/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 47/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 48/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0032 - val_loss: 0.0025
# Epoch 49/50
# 287/287 [==============================] - 1s 4ms/step - loss: 0.0031 - val_loss: 0.0020
# Epoch 50/50
# 287/287 [==============================] - 1s 5ms/step - loss: 0.0030 - val_loss: 0.0028

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title("Training and Validation Loss")
plt.legend()

plt.show()

# %%
original = pd.DataFrame(min_max_scaler.inverse_transform(y_test))
predictions = pd.DataFrame(min_max_scaler.inverse_transform(model.predict(x_test)))

ax = sns.lineplot(x=original.index, y=original[0], label="Test Data", color='royalblue')
ax = sns.lineplot(x=predictions.index, y=predictions[0], label="Prediction", color='tomato')
ax.set_title('Bitcoin price', size = 14, fontweight='bold')
ax.set_xlabel("Days", size = 14)
ax.set_ylabel("Cost (USD)", size = 14)
ax.set_xticklabels('', size=10)
# Out:
# []
